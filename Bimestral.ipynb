# %% [markdown]
# <a href="https://colab.research.google.com/github/axlynaylyngarcia/Bimestral_4to/blob/main/Bimestral.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt 
import numpy as np
from numpy import linspace, log

# %%
print("---------------------------------------")
print("---------Gráfica de funciones----------")
print("---------------------------------------")
print("--Elige la opción que quieras grafica--")
print("---------------------------------------")

print("1.Lineal")
print("2.Cuadrática")
print("3.Cúbica")
print("4.Logarítmica")
print("5.Exponencial")
print("6.Trigonométrica(Seno, Coseno)")
print("             ")

opcion=int(input ("Escoga su opción"))

if opcion ==1 :
  N = 100
  
  def funcion_lineal(m,x,b):
   return m*x + b 
   
  print("---------------------")
  print("---Funcion lineal----")
  print("---y = mx + b--------")
  print("---------------------")

  m = int(input(" Digite el valor de la pendiente"))
  b = int(input("Digite el valor del punto de corte con el eje y: "))

  
  x = np.linspace(-10, 10, num = N)
  y = funcion_lineal(m,x,b)

  plt.plot(x,y, color = 'r')
  plt.xlabel('x')
  plt.ylabel('y')
  plt.title('Funcion lineal: y =mx + b')
  plt.grid()
  plt.axhline(y=0, color= 'b')
  plt.axvline(x=0, color= 'b')
  plt.show()
  plt.savefig('Funcion_lineal.png') 

if opcion==2:
  N = 100 
  
  def funcion_cuadrática():
    return a* x **2 + b* x + c
  
  a = int(input(" Digite el valor de a:"))
  b = int(input(" Digite el valor de b:"))
  c = int(input(" Digite el valor de c:"))
  
  x = np.linspace(-10, 10, num = N)
  y = funcion_cuadrática()

  plt.plot(x,y, color = 'r')
  plt.xlabel('x')
  plt.ylabel('y')
  plt.title('Funcion cuadrática: y =a* x **2 + b* x + c')
  plt.grid()
  plt.axhline(y=0, color= 'b')
  plt.axvline(x=0, color= 'b')
  plt.show()
  plt.savefig('Funcion_cuadratica.png') 

if opcion ==3 :
  N = 100
    
  def funcion_cubica():
        return a* x **3 + b* x **2 + c* x + d
          
  a = int(input(" Digite el valor de a:"))
  b = int(input(" Digite el valor de b:"))
  c = int(input(" Digite el valor de c:"))
  d = int(input(" Digite el valor de d:"))

  x = np.linspace(-10, 10, num = N)
  y = funcion_cubica()

  plt.plot(x,y, color = 'r')
  plt.xlabel('x')
  plt.ylabel('y')
  plt.title('Funcion cubica: y =a* x **3 + b* x **2 + c* x + d')
  plt.grid()
  plt.axhline(y=0, color= 'b')
  plt.axvline(x=0, color= 'b')
  plt.show()
  plt.savefig('Funcion_cubica.png') 
    
if opcion== 4:
  N = 100 

  def funcion_logaritmica():
    return log(x) 

  x = np.linspace(-10, 10, num = N)
  y = funcion_logaritmica()

  plt.plot(x,y, color = 'r')
  plt.xlabel('x')
  plt.ylabel('y')
  plt.title('Funcion logaritmica: y = a + b ')
  plt.grid()
  plt.axhline(y=0, color= 'b')
  plt.axvline(x=0, color= 'b')
  plt.show()
  plt.savefig('Funcion_logaritmica.png')

if opcion== 5:
  N = 100

  def funcion_exponencial(a):
    return a**x

  a = int(input(" Digite el valor de a:"))   

  x = np.linspace(-10, 10, num = N)
  y = funcion_exponencial(a)

  plt.plot(x,y, color = 'r')
  plt.xlabel('x')
  plt.ylabel('y')
  plt.title('Funcion exponencial y = a* x ')
  plt.grid()
  plt.axhline(y=0, color= 'b')
  plt.axvline(x=0, color= 'b')
  plt.show()
  plt.savefig('Funcion_exponencial.png')


if opcion== 6:
  N = 100
  def trig():
    op=int(input("\nDigite 1 para el Seno, 2 Para el Coseno. Digite: "))
if opcion==1:
    x= np.linspace(-np.pi, np.pi, 256)
    y=np.sin(x)

    plt.plot(x,y)
    plt.ylim(-2,2)
    plt.show()

    trig()

elif opcion==2:
    x= np.linspace(-np.pi, np.pi, 256)
    y=np.cos(x)

    plt.plot(x,y)
    plt.ylim(-2,2)
    plt.show()
    trig()
# Out:
# ---------------------------------------
# ---------Gráfica de funciones----------
# ---------------------------------------
# --Elige la opción que quieras grafica--
# ---------------------------------------
# 1.Lineal
# 2.Cuadrática
# 3.Cúbica
# 4.Logarítmica
# 5.Exponencial
# 6.Trigonométrica(Seno, Coseno)
#
# Escoga su opción6
